# %%
print("Hello World!")
print("Day-1: Python Print Function")
print("The function is declared like this:")
print("print('what to print')")
print("Hello" + input("What is your name") + "!")
print(" No of digits" + " " + str(len(input("What is your name?"))))
length = len(input("What is your name?"))
print(length)
# Out:
# Hello World!
# Day-1: Python Print Function
# The function is declared like this:
# print('what to print')
# What is your name
# Hello!
# What is your name?errugyf
#  No of digits 7
# What is your name?erhfgre
# 7

# %%
a=2
b=4

c = a
a = b
b = c
print(a, b)
# Out:
# 4 2

# %%
print("Hello Hows it is")
a= input("In which city you born: \n")
b = input("Your pet name: \n")
print("Your bond name is " + a + " "+ b)
# Out:
# Hello Hows it is
# In which city you born:
# erkfjerfj
# Your pet name:
# fhrjfherjk
# Your bond name is erkfjerfj fhrjfherjk
