# %% [markdown]
# If Else

# %%
height = int(input("Please enter your height: "))
if height > 120:
  print("You are egligible")
else:
  print("Sorry you are not taller enough to ride")
# Out:
# Please enter your height: 120
# Sorry you are not taller enough to ride

# %% [markdown]
# Challenge

# %%
number = int(input("Please enter the number you want to check"))
if number % 2 == 1:
  print("The given nyumber is odd")
else:
  print("The given number is even")
# Out:
# Please enter the number you want to check56
# The given number is even

# %%
height = int(input("Please enter your height: "))
if height > 120:
  age  = int(input("PLease enter your age"))
  print("Hurray you are egligible for a rollercoaster ride")
  if age >= 18:
    print("You have to pay 10 $")
  elif age >= 10:
    print("You have to pay 7 $")
  else:
    print("You are free to go as ticket of juvinile is free")
else:
  print("Sorry you are not taller enough to ride")
# Out:
# Please enter your height: 123
# PLease enter your age5
# Hurray you are egligible for a rollercoaster ride
# You are free to go as ticket of juvinile is free

# %% [markdown]
# ADvance BMI

# %%
height = float(input("Please enter your height"))
weight = float(input("Please enter your weight"))
bmi= round(weight / height ** 2)
if bmi < 18.5:
  print(f"your bmi is {bmi}, You are under weight")
elif bmi > 18.5 and bmi < 25:
  print(f"your bmi is {bmi},You have normal weight")
elif bmi > 25 and bmi < 30:
  print(f"your bmi is {bmi},You are over weight")
elif bmi > 30 and bmi < 35:
  print(f"your bmi is {bmi},You are obese")
else:
  print(f"your bmi is {bmi},You are clinically obese")
# Out:
# Please enter your height1.2
# Please enter your weight56
# your bmi is 39,You are clinically obese

# %% [markdown]
# Leap Year Challenge

# %%
year = int(input("Please enter year you want to check"))
x = year % 4
if x ==  0:
  print(f"{year}, is a leap year")
elif:
  print(f"{year}, is not a leap year")
# Out:
# Please enter year you want to check2022
# 2022, is not a leap year

# %%
print(18 % 4)
# Out:
# 2

# %% [markdown]
# Multi If statement

# %%
height = int(input("Please enter your height: "))
adult = 10
child = 5
mid = 7
juv = 0
photo = 3
if height > 120:
  age  = int(input("PLease enter your age"))
  print("Hurray you are egligible for a rollercoaster ride")
  if age > 18:
    photos = bool(input("Do you want to have photos"))
    if photos == True:
     totalbill = adult + int(photo)
     print(f"Your bill is {totalbill}, $")
    else:
      print(f"Your bill is {adult}, $")
  elif age <  18 and age > 10:
    photos = bool(input("Do you want to have photos"))
    if photos == True:
     totalbill = mid + int(photo)
     print(f"Your bill is {totalbill}, $")
    else:
      print(f"Your bill is {mid}, $")
  elif age <= 10:
    photos = bool(input("Do you want to have photos"))
    if photos == True:
     totalbill = child + int(photo)
     print(f"Your bill is {totalbill}, $")
    else:
      print(f"Your bill is {child}, $")
  else:
    photos = bool(input("Do you want to have photos"))
    if photos == True:
     totalbill = juv + int(photo)
     print(f"You are free to go as ticket of juvinile is free but photo cost is {totalbill} $")
    else:
      print(f"Your bill is {adult},$")


else:
  print("Sorry you are not taller enough to ride")
# Out:
# Please enter your height: 145
# PLease enter your age8
# Hurray you are egligible for a rollercoaster ride
# Do you want to have photosYes
# Your bill is 8, $

# %% [markdown]
# more precise code

# %%
height = int(input("Please enter your height: "))
if height > 120:
  age  = int(input("PLease enter your age"))
  print("Hurray you are egligible for a rollercoaster ride")
  if age > 18:
    bill = int(10)
    print("Afults tickets are $10")
  elif age <  18 and age > 10:
    bill = int(7)
    print("Child tickets are $7")
  else:
     bill = int(5)
     print("Juvenile tickets are $10")
  want_photos = input("Would you like to have photos: Y / N")
  if want_photos == "Y":
    bill += 3
    print(f"You total bill is {bill}")

else:
  print("Sorry you are not taller enough to ride")
# Out:
# Please enter your height: 145
# PLease enter your age15
# Hurray you are egligible for a rollercoaster ride
# Child tickets are $7
# Would you like to have photos: Y / NY
# You total bill is 10

# %% [markdown]
# Pizza shop

# %%
print("Welcome to Pizza Shop")
size = input("Please enter the size of pizza: S, L, M")
add_pepporoni = input("You want to add peporroni: Y / N")
extra_cheese = input("Would you like to add extra cheese: Y/N")
if size == "S":
  pizza = 15
  print("Small pizza cost 15 $")
  if add_pepporoni == "Y":
    pizza +=2
  if extra_cheese == "Y":
    pizza += 1
  print(f"Your bill is {pizza}, $")
elif size == "M":
  pizza = 20
  print("Medium pizza cost 20 $")
  if add_pepporoni == "Y":
    pizza +=3
  if extra_cheese == "Y":
    pizza += 1
  print(f"Your bill is {pizza}, $")
elif size == "L":
  pizza = 25
  print("Medium pizza cost 25 $")
  if add_pepporoni == "Y":
    pizza +=3
  if extra_cheese == "Y":
    pizza += 1
  print(f"Your bill is ${pizza}")

else:
  print("You made a wrong entry")
# Out:
# Welcome to Pizza Shop
# Please enter the size of pizza: S, L, ML
# You want to add peporroni: Y / NY
# Would you like to add extra cheese: Y/NY
# Medium pizza cost 25 $
# Your bill is 29, $

# %% [markdown]
# Logical operator

# %%
height = int(input("Please enter your height: "))
if height > 120:
  age  = int(input("PLease enter your age"))
  print("Hurray you are egligible for a rollercoaster ride")
  if age == 18:
    bill = int(10)
    print("Afults tickets are $10")
  elif age <  18 and age > 10:
    bill = int(7)
    print("Child tickets are $7")
  elif age < 10:
    bill = int(5)
    print("Juvenile tickets are $10")
  elif age > 40 and age < 45:
    bill = int(0)
    print("Old are free")
  want_photos = input("Would you like to have photos: Y / N")
  if want_photos == "Y":
    bill += 3
    print(f"You total bill is {bill}")

else:
  print("Sorry you are not taller enough to ride")
# Out:
# Please enter your height: 145
# PLease enter your age44
# Hurray you are egligible for a rollercoaster ride
# Old are free
# Would you like to have photos: Y / NY
# You total bill is 3

# %% [markdown]
# LOVE CALCULATOR

# %%
print("Welcome to the Love Calculator")
your_name = input("Please enter your name")
their_name = input("Please enter their name")

combined_string = your_name + their_name
low_string = combined_string.lower()

t = low_string.count("t")
r = low_string.count("r")
u = low_string.count("u")
e = low_string.count("e")

true = t + r + u + e

l = low_string.count("l")
o = low_string.count("o")
v = low_string.count("v")
e = low_string.count("e")

love = l + o + v + e

love_score = int(str(true) + str(love))

print(love_score)

if love_score < 10 or love_score > 90:
  print(f"Your love score is {love_score} you go together like coke and mentos")
elif love_score > 40 and love_score <50:
  print(f"You score is {love_score}, you are alrigh together")
else:
  print(f"Your score is {love_score}")
# Out:
# Welcome to the Love Calculator
# Please enter your nameTehseen
# Please enter their nameSaid
# 43
# You score is 43, you are alrigh together

# %% [markdown]
# Treasure Island project

# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/[TomekK]
*******************************************************************************
''')
print("Welcome to the Treasure Land")
print("Your mission is to find treasure")
turn = input("In which direction you want to turn? left ot right").lower()
if turn == "left":
  swim = input("DO you want to swim or wait").lower()
  if swim == "wait":
    door = input("Which color of door you want to use blue, red or yellow").lower()
    if door == "yellow":
      print("Congrats you win")
    else:
      print("you lost")
  else:
    print("you lost")
else:
  print("you lost")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
