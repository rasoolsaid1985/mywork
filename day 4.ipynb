# %% [markdown]
# Randomization

# %%
import random

# %%
random_int = random.randint(1,10)
print(random_int)

random_float = random.random() #it will always give betweeen 0.0 to o.99999
print(random_float)
# Out:
# 5
# 0.9327817213832191

# %%
random_float = random.random() * 5
print(random_float)
# Out:
# 2.6395981222293132

# %%
love_Score = random.randint(1, 100)
print(f"Your lovw score is {love_Score}")
# Out:
# Your lovw score is 51

# %% [markdown]
# Randomization and list

# %%
name_string = input("PLease enter the name of the people who has dinner today")
name = name_string.split(",")
total = len(name)

paid = random.randint(0,total - 1)
print(paid)
print(f"Hey {name[paid]} will pay todays bill")
# Out:
# PLease enter the name of the people who has dinner todayAli, Ahmed, Hassan, Khan
# 3
# Hey  Khan will pay todays bill

# %%
friends = ["A", "V", "C", "C"]
friends[1] = "B"
print(friends)
friends.extend(["D", "E", "F"])
print(friends)
print(len(friends))
# Out:
# ['A', 'B', 'C', 'C']
# ['A', 'B', 'C', 'C', 'D', 'E', 'F']
# 7

# %% [markdown]
# Nested List

# %%
enemy = ["F", "G", "K", "L"]
combine = [friends , enemy]
print(combine)
# Out:
# [['A', 'B', 'C', 'C', 'D', 'E', 'F'], ['F', 'G', 'K', 'L']]

# %% [markdown]
# CHALLENGE

# %%
row1 = ["🥲", "🥹", "😂"]
row2 = ["🥹", "😂", "🥲"]
row3 = ["😂", "🥲", "🥹"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure")

horizontal = int(position[0])
vertical = int(position[1])

selected_row = map[vertical-1]
selected_row[horizontal-1] = "X"
print(map)
# Out:
# ['🥲', '\U0001f979', '😂']
# ['\U0001f979', '😂', '🥲']
# ['😂', '🥲', '\U0001f979']
# Where do you want to put the treasure23
# [['🥲', '\U0001f979', '😂'], ['\U0001f979', '😂', '🥲'], ['😂', 'X', '\U0001f979']]

# %% [markdown]
# Project

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

# Paper
paper = '''
     _______
---'    ____)____
           ______)
          _______)
         _______)
---.__________)
'''

# Scissors
scissor = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

print(rock)
# Out:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)

# %%
import random
user = int(input("Please enter 0 for rock, 1 for scissor, and 2 for paper"))
images = [rock, paper, scissor]
print(images[user])

computer = random.randint(0,2)
print(images[computer])


if user == 0 and computer == 1:
  print("u win")
elif user == 0 and computer == 2:
  print("u win")
elif user == 1 and computer == 2:
  print("u win")
elif user == computer:
  print("Try agains")
else:
  print("player 2 win")
# Out:
# Please enter 0 for rock, 1 for scissor, and 2 for paper1
#
#      _______
# ---'    ____)____
#            ______)
#           _______)
#          _______)
# ---.__________)
#
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# player 2 win
